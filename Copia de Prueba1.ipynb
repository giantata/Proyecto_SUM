# %%
print('Prueba')
# Out:
# Prueba

# %%
# !git init

# %%
# !git add Prueba1.ipynb
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git status -s
# Out:
# fatal: not a git repository (or any of the parent directories): .git
